# %%
import cv2
import matplotlib.pyplot as plt

# 读取图像
image = cv2.imread('fore.png')

# 显示图像的shape
print("Shape of the image:", image.shape)

# 显示图像
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Shape of the image: (800, 800, 3)
